# %%
 import pandas as pd

# %%
df =  pd.read_csv("train.csv")

# %% [markdown]
# ## 1. How big is the data?

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ## 2. How does the data look like

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 82            83         1       3  McDermott, Miss. Brigdet Delia  female
# 159          160         0       3      Sage, Master. Thomas Henry    male
# 173          174         0       3       Sivola, Mr. Antti Wilhelm    male
# 868          869         0       3     van Melkebeke, Mr. Philemon    male
# 256          257         1       1  Thorne, Mrs. Gertrude Maybelle  female
#
#       Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# 82    NaN      0      0             330932   7.7875   NaN        Q
# 159   NaN      8      2           CA. 2343  69.5500   NaN        S
# 173  21.0      0      0  STON/O 2. 3101280   7.9250   NaN        S
# 868   NaN      0      0             345777   9.5000   NaN        S
# 256   NaN      0      0           PC 17585  79.2000   NaN        C

# %% [markdown]
# ## 3. What is the data type of cols?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## 4. Are there any missing values?

# %%
df.isnull().sum()        # df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## 5. How does the data look mathematically?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## 6. Are there duplicate values?

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 7. How is the correlation between cols?

# %% [markdown]
# correlation means : Ek chiz ke badhne ke ghatne se dusre chiz pr kya asar pdd rha hai

# %% [markdown]
# ![image.png](attachment:4001bbf6-3e5b-416c-8bab-559f7ea07c52.png)

# %% [markdown]
#  yha hmne 'output'/'target' variable ko dala hai to check ki uske sath kaisa corr bnn rha hai
#  1. dare >  strong/+ve correlaton
#  2. patch > +ve correlation
#  3. Pclass > storng  -ve Correlation
#  4. NOTE: 'PassengerID' > 0.00 something that is not impt to include when we train the model
